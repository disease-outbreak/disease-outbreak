# %%
import pandas as pd
import os
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv('chronic_disease2014.csv')

# %% [markdown]
# Cardiovascular Disease
# Alcohol
# Arthritis
# Asthma
# Cancer
# Chronic Kidney Disease
# Chronic Obstructive Pulmonary Disease
# Mental Health
# Tobacco
# Overarching Conditions
# Oral Health
# Reproductive Health
# Diabetes
# Immunization
# Nutrition, Physical Activity, and Weight Status
# Disability
# Older Adults

# %% [markdown]
# - Cardiovascular Disease (Heart attack)
# - Alcohol(alcoholic hepatitis)
# - Chronic Kidney Disease (Hypertension, Diabetes, Hypothyroidism, Jaundice, Malaria, Osteoarthristis, Paralysis (brain hemorrhage)
# - Reproductive Health ( hepatitis,UTI, Gastroenteritis)
# - Nutrition, Physical Activity, and Weight Status ( diabetics, Hypertension(HBP), Migraine, Allergy, GERD)
# - Tobacco (

# %%
# idetify unique valuse in the datasource column
unique_data_sources = df1['DataSource'].unique()
unique_data_sources
# Out:
# array(['NVSS', 'YRBSS', 'PRAMS', 'BRFSS', 'SEDD; SID',
#        'Statewide central cancer registries', 'Death Certificate',
#        'USRDS', 'CMS Part A Claims Data', 'ACS 1-Year Estimates',
#        'CMS CCW', 'HRSA, UDS', 'WFRS', 'NVSS, Mortality',
#        'Legal Research', 'APIS', 'AEDS', 'Birth Certificate, NVSS',
#        'NSCH', 'Current Population Survey',
#        'CDC Breastfeeding Report Card', 'CDC School Health Profiles',
#        'National Immunization Survey', 'mPINC',
#        "CDC Children's Food Environment State Indicator Report",
#        "USDA National Farmers' Market Directory", 'InfoUSA; USDA', 'ASHW',
#        'STATE', 'ACS 5-Year Estimates', 'ANRF'], dtype=object)

# %%
# Filter the dataset to select only rows where DataSource is Death Certificate
death_certificate_data = df1[df1['DataSource'] == 'Death Certificate']

# %%
death_certificate_data.head()
# Out:
#      YearStart  YearEnd LocationAbbr    LocationDesc         DataSource  \
# 281       2010     2014           IL        Illinois  Death Certificate
# 282       2012     2016           MN       Minnesota  Death Certificate
# 283       2009     2013           NC  North Carolina  Death Certificate
# 284       2009     2013           ND    North Dakota  Death Certificate
# 285       2010     2014           SC  South Carolina  Death Certificate
#
#       Topic                                          Question  Response  \
# 281  Cancer  Cancer of the oral cavity and pharynx, mortality       NaN
# 282  Cancer  Cancer of the oral cavity and pharynx, mortality       NaN
# 283  Cancer  Cancer of the oral cavity and pharynx, mortality       NaN
# 284  Cancer  Cancer of the oral cavity and pharynx, mortality       NaN
# 285  Cancer  Cancer of the oral cavity and pharynx, mortality       NaN
#
#     DataValueUnit          DataValueType DataValue  DataValueAlt  \
# ...

# %%
# Get the number of rows in the filtered dataset
num_rows_filtered = death_certificate_data.shape[0]
num_rows_total = df1.shape[0]
num_rows_filtered, num_rows_total
# Out:
# (79872, 1185676)

# %%
selected_topics = [
    'Cardiovascular Disease',
    'Alcohol',
    'Chronic Kidney Disease',
    'Reproductive Health',
    'Nutrition, Physical Activity, and Weight Status',
    'Tobacco'
]

# %%
#filter data for selected topics
filtered_datasets = {}
for topic in selected_topics:
    filtered_datasets[topic] = death_certificate_data[death_certificate_data['Topic'] == topic]

# %%
# Identify the unique values in the topic column within the Death Certificate data
death_certificate_topic = death_certificate_data['Topic'].unique()
death_certificate_topic.tolist()
# Out:
# ['Cancer']

# %%
df1['DataSource'] == 'Death Certific'
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0       2010     2010           OR          Oregon       NVSS
# 1       2019     2019           AZ         Arizona      YRBSS
# 2       2019     2019           OH            Ohio      YRBSS
# 3       2019     2019           US   United States      YRBSS
# 4       2015     2015           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  Response  \
# 0  Cardiovascular Disease  Mortality from heart failure       NaN
# 1                 Alcohol       Alcohol use among youth       NaN
# 2                 Alcohol       Alcohol use among youth       NaN
# 3                 Alcohol       Alcohol use among youth       NaN
# 4                 Alcohol       Alcohol use among youth       NaN
#
#   DataValueUnit     DataValueType DataValue  DataValueAlt  \
# 0           NaN            Number        30          30.0
# 1             %  Crude Prevalence      29.5          29.5
# ...
