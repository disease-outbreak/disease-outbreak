# %%
import pandas as pd
import os
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#data collected from data.gov
data = pd.read_csv('Death_by_select_casue.csv')

# %% [markdown]
# - Septicemia
# - Malignant Neoplasms (Cancer)
# - Diabetes Mellitus
# - Alzheimer Disease
# - Influenza and Pneumonia
# - Chronic Lower Respiratory Diseases
# - Other Diseases of the Respiratory System
# - Nephritis, Nephrotic Syndrome and Nephrosis (Kidney Diseases)
# - Symptoms, Signs and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified
# - Diseases of Heart
# - Cerebrovascular Diseases (Stroke)

# %% [markdown]
# - septicemia = Pneumonia, TB, Hepaticis, Dengue, Typhoid
# - Diabetics Mellitus - Hypertension, chronic kidney disease, gastroenteritis, Arthritis
# - Influenza and Pnewmonia -  Common cold, Pneumonia,
# - Chronic Lower Respiratory disease - Bronchial asthma
# - Nephritis, Nephrotic Syndrome and Nephrosis (Kidney Diseases) - Hypertension
# - Cerebrovascular Diseases (Stroke) - Paralysis(brain hemorrhage

# %%
#  selected  specified conditions
selected_columns = [
    'Data As Of', 'Start Date', 'End Date', 'Jurisdiction of Occurrence', 'Year', 'Month',
    'Septicemia', 'Diabetes Mellitus', 'Influenza and Pneumonia', 
    'Chronic Lower Respiratory Diseases', 'Nephritis, Nephrotic Syndrome and Nephrosis', 
    'Cerebrovascular Diseases'
]

# %%
# Filter the dataset
filtered_data = data[selected_columns]
filtered_data
# Out:
#     Data As Of  Start Date    End Date Jurisdiction of Occurrence  Year  \
# 0   09/27/2023  01/01/2020  01/31/2020              United States  2020
# 1   09/27/2023  02/01/2020  02/29/2020              United States  2020
# 2   09/27/2023  03/01/2020  03/31/2020              United States  2020
# 3   09/27/2023  04/01/2020  04/30/2020              United States  2020
# 4   09/27/2023  05/01/2020  05/31/2020              United States  2020
# 5   09/27/2023  06/01/2020  06/30/2020              United States  2020
# 6   09/27/2023  07/01/2020  07/31/2020              United States  2020
# 7   09/27/2023  08/01/2020  08/31/2020              United States  2020
# 8   09/27/2023  09/01/2020  09/30/2020              United States  2020
# 9   09/27/2023  10/01/2020  10/31/2020              United States  2020
# 10  09/27/2023  11/01/2020  11/30/2020              United States  2020
# 11  09/27/2023  12/01/2020  12/31/2020              United States  2020
# ...

# %%
selected_years = [2020, 2021, 2022]

# %%
# Filter the dataset based on the selected years
filtered_data_by_years = filtered_data[filtered_data['Year'].isin(selected_years)]
filtered_data_by_years
# Out:
#     Data As Of  Start Date    End Date Jurisdiction of Occurrence  Year  \
# 0   09/27/2023  01/01/2020  01/31/2020              United States  2020
# 1   09/27/2023  02/01/2020  02/29/2020              United States  2020
# 2   09/27/2023  03/01/2020  03/31/2020              United States  2020
# 3   09/27/2023  04/01/2020  04/30/2020              United States  2020
# 4   09/27/2023  05/01/2020  05/31/2020              United States  2020
# 5   09/27/2023  06/01/2020  06/30/2020              United States  2020
# 6   09/27/2023  07/01/2020  07/31/2020              United States  2020
# 7   09/27/2023  08/01/2020  08/31/2020              United States  2020
# 8   09/27/2023  09/01/2020  09/30/2020              United States  2020
# 9   09/27/2023  10/01/2020  10/31/2020              United States  2020
# 10  09/27/2023  11/01/2020  11/30/2020              United States  2020
# 11  09/27/2023  12/01/2020  12/31/2020              United States  2020
# ...

# %%
# Defineed the diseases to be added together
diseases_to_sum = ['Septicemia', 'Diabetes Mellitus', 'Chronic Lower Respiratory Diseases']
